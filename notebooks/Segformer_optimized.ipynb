# %%
# ============================================================
# CELL 1 - Environment Setup
# Install all required dependencies for MMSegmentation + SegFormer
# ============================================================

# Install PyTorch with CUDA 12.1 support
# !pip install torch==2.4.1 torchvision==0.19.1 --index-url https://download.pytorch.org/whl/cu121 -q

# Install OpenMMLab stack
# !pip install mmengine -q
# !pip install mmcv==2.2.0 -f https://download.openmmlab.com/mmcv/dist/cu121/torch2.4/index.html -q
# !pip install mmsegmentation -q

# Fix mmcv version check (mmseg 1.2.2 hardcodes max version as 2.2.0 exclusive)
# !sed -i 's/MMCV_MAX = .2.2.0./MMCV_MAX = "2.3.0"/' \
    /usr/local/lib/python3.12/dist-packages/mmseg/__init__.py

# Install text encoding dependencies
# !pip install ftfy -q

# Install additional augmentation library
# !pip install albumentations -q

print("Installation complete, version check fixed!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 84.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 66.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 59.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 113.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.4.1+cu121 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 77.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
# Installation complete, version check fixed!

# %%
# ============================================================
# CELL 2 - Environment Verification
# Verify all packages are correctly installed and GPU is available
# ============================================================

import torch, mmcv, mmengine, mmseg

print('torch:', torch.__version__)
print('mmcv:', mmcv.__version__)
print('mmseg:', mmseg.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# torch: 2.4.1+cu121
# mmcv: 2.2.0
# mmseg: 1.2.2
# CUDA available: True
# GPU: Tesla T4

# %%
# ============================================================
# CELL 3 - Mount Google Drive and Extract Dataset
# ============================================================

from google.colab import drive
drive.mount('/content/drive')

# Extract dataset from Drive to Colab local storage (faster I/O during training)
# !unzip -q /content/drive/MyDrive/Dataset/processed.zip -d /content/

# Verify dataset structure and image counts
print("=== Dataset Verification ===")
# !echo "Train images:" && ls /content/processed/train/images/ | wc -l
# !echo "Train masks: " && ls /content/processed/train/masks/  | wc -l
# !echo "Val images:  " && ls /content/processed/val/images/   | wc -l
# !echo "Val masks:   " && ls /content/processed/val/masks/    | wc -l
# !echo "Test images: " && ls /content/processed/test/images/  | wc -l
# !echo "Test masks:  " && ls /content/processed/test/masks/   | wc -l
# Out:
# Mounted at /content/drive
# === Dataset Verification ===
# Train images:
# 672
# Train masks:
# 672
# Val images:
# 149
# Val masks:
# 149
# Test images:
# 146
# Test masks:
# 146

# %%
# ============================================================
# CELL 4 - Clone Repository and Download Pretrained Weights
# ============================================================
import os
import shutil

repo_path = '/content/repo'

# 1. Move out of the directory before deleting it
# %cd /content

# 2. Clean up existing repo safely
if os.path.exists(repo_path):
    shutil.rmtree(repo_path)
    print(f"Cleaned up existing repository at {repo_path}")

# 3. Clone the project repository
# !git clone https://github.com/ilMassy/advertising-panel-segmentation {repo_path}

# 4. Change directory into the new repo
# %cd {repo_path}

# 5. Create necessary directories
os.makedirs(os.path.join(repo_path, 'results'), exist_ok=True)
os.makedirs(os.path.join(repo_path, 'models'), exist_ok=True)
os.makedirs('/content/checkpoints', exist_ok=True)  # fuori dal repo

# 6. Download MIT-B1 pretrained weights
# !wget -q --show-progress \
    https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segformer/mit_b1_20220624-02e5a6a1.pth \
    -O /content/checkpoints/mit_b1_imagenet.pth

print("\nSetup completed successfully!")
# !ls -lh /content/checkpoints/
# Out:
# /content
# Cloning into '/content/repo'...
# remote: Enumerating objects: 298, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 298 (delta 62), reused 67 (delta 28), pack-reused 190 (from 1)
# Receiving objects: 100% (298/298), 328.94 KiB | 2.33 MiB/s, done.
# Resolving deltas: 100% (160/160), done.
# /content/repo
# /content/checkpoint 100%[===================>]  50.22M  14.6MB/s    in 5.4s
#
# Setup completed successfully!
# total 51M
# -rw-r--r-- 1 root root 51M Jun 24  2022 mit_b1_imagenet.pth

# %%
# ============================================================
# CELL 5 - Verify Repository Structure
# ============================================================

import os

# Verify all files were cloned correctly
# !echo "=== Config files ===" && ls /content/repo/configs/
# !echo "=== Source scripts ===" && ls /content/repo/src/
# !echo "=== Results directory ===" && ls /content/repo/results/
# !echo "=== Models directory ===" && ls /content/repo/models/

# Verify dataset
# !echo "=== Dataset ==="
# !ls /content/processed/

print("Repository structure verified!")
# Out:
# === Config files ===
# segformer_b0_baseline.py   segformer_b1_optimized.py
# segformer_b1_augmented.py  segformer_b1_standard.py
# === Source scripts ===
# check_masks.py	CVAT_preparation.py  extract_frames.py	reorder_by_prefix.py
# === Results directory ===
# exp0_segformer_b0_baseline  exp2_segformer_b1_augmented
# exp1_segformer_b1_standard
# === Models directory ===
# README.md
# === Dataset ===
# test  train  val
# Repository structure verified!

# %%
# ============================================================
# CELL 6 - Create Optimized Config
# SegFormer-B1 with refined strategy:
# - LR 3e-5 for stable convergence
# - Decoder channels = 512
# - Refined Albumentations (Sharper edges, CoarseDropout)
# - Pure CrossEntropy Loss (Pixel-perfect precision)
# ============================================================


import os
os.makedirs('/content/repo/configs', exist_ok=True)

segformer_b1_optimized_config = """
_base_ = [
    'mmseg::_base_/models/segformer_mit-b0.py',
    'mmseg::_base_/default_runtime.py',
]

# Dataset settings
dataset_type = 'BaseSegDataset'
data_root    = '/content/processed/'
crop_size    = (640, 640)

# Training pipeline (same augmentations as Phase 4)
train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='RandomResize', scale=(1920, 1080), ratio_range=(0.5, 2.0), keep_ratio=True),
    dict(type='RandomCrop', crop_size=crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PhotoMetricDistortion'),
    dict(
        type='Albu',
        transforms=[
            dict(type='MotionBlur', blur_limit=5, p=0.3),
            dict(type='GaussNoise', var_limit=(5, 30), p=0.2),
            dict(type='RandomBrightnessContrast',
                 brightness_limit=0.3,
                 contrast_limit=0.3, p=0.4),
            dict(type='HueSaturationValue',
                 hue_shift_limit=20,
                 sat_shift_limit=30,
                 val_shift_limit=20, p=0.3),
            dict(type='CoarseDropout',
                 max_holes=4,
                 max_height=60,
                 max_width=60,
                 min_holes=1,
                 fill_value=0, p=0.25),
        ],
        keymap={'img': 'image', 'gt_semantic_seg': 'mask'},
        update_pad_shape=False,
    ),
    dict(type='PackSegInputs'),
]

# Validation/Test pipeline (no augmentation)
val_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(1920, 1080), keep_ratio=True),
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs'),
]

# Dataset meta info (2 classes: background and board)
meta = dict(
    classes=('background', 'board'),
    palette=[[0, 0, 0], [255, 0, 0]]
)

# Dataloaders
train_dataloader = dict(
    batch_size=4, num_workers=2,
    dataset=dict(
        type=dataset_type, data_root=data_root,
        data_prefix=dict(img_path='train/images', seg_map_path='train/masks'),
        img_suffix='.jpeg', seg_map_suffix='.png',
        metainfo=meta, pipeline=train_pipeline,
    )
)

val_dataloader = dict(
    batch_size=1, num_workers=2,
    dataset=dict(
        type=dataset_type, data_root=data_root,
        data_prefix=dict(img_path='val/images', seg_map_path='val/masks'),
        img_suffix='.jpeg', seg_map_suffix='.png',
        metainfo=meta, pipeline=val_pipeline,
    )
)

# Test set separated from validation
test_dataloader = dict(
    batch_size=1, num_workers=2,
    dataset=dict(
        type=dataset_type, data_root=data_root,
        data_prefix=dict(img_path='test/images', seg_map_path='test/masks'),
        img_suffix='.jpeg', seg_map_suffix='.png',
        metainfo=meta, pipeline=val_pipeline,
    )
)

# Evaluation metrics
val_evaluator  = dict(type='IoUMetric', iou_metrics=['mIoU', 'mDice'])
test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU', 'mDice', 'mFscore'])

# Model: SegFormer-B1
# Only change: LR 3e-5 instead of 6e-5
model = dict(
    data_preprocessor=dict(
        type='SegDataPreProcessor',
        mean=[123.675, 116.28, 103.53],
        std=[58.395, 57.12, 57.375],
        bgr_to_rgb=True,
        pad_val=0,
        seg_pad_val=255,
        size=crop_size,
        size_divisor=None,
    ),
    backbone=dict(
        embed_dims=64,
        num_heads=[1, 2, 5, 8],
        num_layers=[2, 2, 2, 2],
        drop_path_rate=0.1,
        init_cfg=dict(
            type='Pretrained',
            checkpoint='/content/checkpoints/mit_b1_imagenet.pth'
        )
    ),
    decode_head=dict(
        in_channels=[64, 128, 320, 512],
        num_classes=2,
        channels=512,
        dropout_ratio=0.1,
        loss_decode=dict(
            type='CrossEntropyLoss',
            loss_weight=1.0,
            use_sigmoid=False
        ),
    ),
    test_cfg=dict(mode='whole')
)

# AdamW optimizer - lower LR for stable convergence (only architectural change)
optimizer = dict(type='AdamW', lr=3e-5, betas=(0.9, 0.999), weight_decay=0.01)
optim_wrapper = dict(
    type='OptimWrapper',
    optimizer=optimizer,
    paramwise_cfg=dict(
        custom_keys={
            'pos_block': dict(decay_mult=0.),
            'norm':      dict(decay_mult=0.),
            'head':      dict(lr_mult=10.)
        }
    )
)

# LR scheduler with warmup
param_scheduler = [
    dict(type='LinearLR', start_factor=1e-6, by_epoch=False, begin=0,    end=1500),
    dict(type='PolyLR',   eta_min=0.0,       power=1.0,      begin=1500, end=20000, by_epoch=False),
]

# Save best checkpoint based on mIoU
default_hooks = dict(
    checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=2000,
                    max_keep_ckpts=3, save_best='mIoU', rule='greater'),
    logger=dict(type='LoggerHook', interval=50),
)

# Early stopping: stop if val mIoU does not improve for 5 consecutive validations
custom_hooks = [
    dict(
        type='EarlyStoppingHook',
        monitor='mIoU',
        rule='greater',
        min_delta=0.001,
        patience=5,
    )
]

train_cfg = dict(type='IterBasedTrainLoop', max_iters=20000, val_interval=2000)
val_cfg   = dict(type='ValLoop')
test_cfg  = dict(type='TestLoop')
"""

# Write config to disk
with open('/content/repo/configs/segformer_b1_optimized.py', 'w') as f:
    f.write(segformer_b1_optimized_config)

print(f"Config successfully created!")
print("\nPhase 5 Summary (Strategic Optimizations):")
print("-" * 50)
print("1. LR: 6e-5 -> 3e-5          (Stable convergence, lower overfitting)")
print("2. Augmentation: Lightened   (Reduced Blur/Noise, Modified CoarseDropout)")
print("3. Decoder channels: 256->512 (Higher capacity for perspective panels)")
print("4. Loss: Pure CrossEntropy   (Focusing on pixel-wise edge precision)")
print("-" * 50)
# !ls -lh /content/repo/configs/
# Out:
# Config successfully created!
#
# Phase 5 Summary (Strategic Optimizations):
# --------------------------------------------------
# 1. LR: 6e-5 -> 3e-5          (Stable convergence, lower overfitting)
# 2. Augmentation: Lightened   (Reduced Blur/Noise, Modified CoarseDropout)
# 3. Decoder channels: 256->512 (Higher capacity for perspective panels)
# 4. Loss: Pure CrossEntropy   (Focusing on pixel-wise edge precision)
# --------------------------------------------------
# total 24K
# -rw-r--r-- 1 root root 3.7K Mar 28 12:04 segformer_b0_baseline.py
# -rw-r--r-- 1 root root 5.0K Mar 28 12:04 segformer_b1_augmented.py
# -rw-r--r-- 1 root root 5.1K Mar 28 12:04 segformer_b1_optimized.py
# -rw-r--r-- 1 root root 3.9K Mar 28 12:04 segformer_b1_standard.py

# %%
# ============================================================
# CELL 7 - Push optimized Config to GitHub
# ============================================================

import os
from getpass import getpass

# Git configuration
# !cd /content/repo && git config user.email "massimilianogiangreco7@gmail.com"
# !cd /content/repo && git config user.name "ilMassy"

# Ask for token securely (input is hidden)
GITHUB_TOKEN = getpass("Enter your GitHub Personal Access Token: ")

# Set remote URL with authentication token
# !cd /content/repo && git remote set-url origin \
    https://{GITHUB_TOKEN}@github.com/ilMassy/advertising-panel-segmentation.git

# Pull remote changes first
# !cd /content/repo && git pull origin main --rebase

# Add and commit config file
# !cd /content/repo && git add configs/
# !cd /content/repo && git commit -m "Add SegFormer-B1 optimized config (Phase 5)" \
    || echo "Nothing to commit, already done"

# Push to GitHub
# !cd /content/repo && git push origin main

print("Config file pushed to GitHub!")
# Out:
# Enter your GitHub Personal Access Token: ··········
# From https://github.com/ilMassy/advertising-panel-segmentation
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Nothing to commit, already done
# Everything up-to-date
# Config file pushed to GitHub!

# %%
# ============================================================
# CELL 8 - Training: SegFormer-B1 Optimized (Phase 5)
# Checkpoints saved directly to Google Drive during training
# ============================================================

import os
import mmseg

# Correct path for mmseg tools on Colab
mmseg_tools = os.path.join(
    os.path.dirname(mmseg.__file__),
    '.mim', 'tools', 'train.py'
)
print(f"MMSeg train tool: {mmseg_tools}")

# Verify tool exists
assert os.path.exists(mmseg_tools), f"train.py not found at {mmseg_tools}"
print("Train tool found!")

# Create output directory on Drive
# !mkdir -p /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized

# Launch B1 optimized training
# work-dir points directly to Drive so checkpoints are saved during training
# !python {mmseg_tools} \
    /content/repo/configs/segformer_b1_optimized.py \
    --work-dir /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized \
    2>&1 | tee /content/training_b1_optimized_log.txt
# Out:
# MMSeg train tool: /usr/local/lib/python3.12/dist-packages/mmseg/.mim/tools/train.py
# Train tool found!
# /usr/local/lib/python3.12/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 03/26 11:56:46 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 611881125
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.8, V12.8.93
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.4.2 (Git Hash 1137e04ec0b5251ca2b4400a4fd3c667ce843d67)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.1  (built against CUDA 12.4)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.4.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.19.1+cu121
#     OpenCV: 4.13.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 611881125
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/26 11:56:46 - mmengine - INFO - Config:
# crop_size = (
#     640,
#     640,
# )
# custom_hooks = [
#     dict(
#         min_delta=0.001,
#         monitor='mIoU',
#         patience=5,
#         rule='greater',
#         type='EarlyStoppingHook'),
# ]
# data_preprocessor = dict(
#     _scope_='mmseg',
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '/content/processed/'
# dataset_type = 'BaseSegDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=2000,
#         max_keep_ckpts=3,
#         rule='greater',
#         save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# meta = dict(
#     classes=(
#         'background',
#         'board',
#     ), palette=[
#         [
#             0,
#             0,
#             0,
#         ],
#         [
#             255,
#             0,
#             0,
#         ],
#     ])
# model = dict(
#     _scope_='mmseg',
#     backbone=dict(
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         drop_rate=0.0,
#         embed_dims=64,
#         in_channels=3,
#         init_cfg=dict(
#             checkpoint='/content/checkpoints/mit_b1_imagenet.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         num_heads=[
#             1,
#             2,
#             5,
#             8,
#         ],
#         num_layers=[
#             2,
#             2,
#             2,
#             2,
#         ],
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_sizes=[
#             7,
#             3,
#             3,
#             3,
#         ],
#         qkv_bias=True,
#         sr_ratios=[
#             8,
#             4,
#             2,
#             1,
#         ],
#         type='MixVisionTransformer'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             640,
#             640,
#         ),
#         size_divisor=None,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=[
#             64,
#             128,
#             320,
#             512,
#         ],
#         in_index=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=2,
#         type='SegformerHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(_scope_='mmseg', requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=3e-05, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             head=dict(lr_mult=10.0),
#             norm=dict(decay_mult=0.0),
#             pos_block=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# optimizer = dict(
#     betas=(
#         0.9,
#         0.999,
#     ), lr=3e-05, type='AdamW', weight_decay=0.01)
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1500, start_factor=1e-06,
#         type='LinearLR'),
#     dict(
#         begin=1500,
#         by_epoch=False,
#         end=20000,
#         eta_min=0.0,
#         power=1.0,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='test/images', seg_map_path='test/masks'),
#         data_root='/content/processed/',
#         img_suffix='.jpeg',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'board',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1920,
#                 1080,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='BaseSegDataset'),
#     num_workers=2)
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ], type='IoUMetric')
# train_cfg = dict(max_iters=20000, type='IterBasedTrainLoop', val_interval=2000)
# train_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         data_prefix=dict(img_path='train/images', seg_map_path='train/masks'),
#         data_root='/content/processed/',
#         img_suffix='.jpeg',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'board',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     1920,
#                     1080,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     640,
#                     640,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(
#                 keymap=dict(gt_semantic_seg='mask', img='image'),
#                 transforms=[
#                     dict(blur_limit=5, p=0.3, type='MotionBlur'),
#                     dict(p=0.2, type='GaussNoise', var_limit=(
#                         5,
#                         30,
#                     )),
#                     dict(
#                         brightness_limit=0.3,
#                         contrast_limit=0.3,
#                         p=0.4,
#                         type='RandomBrightnessContrast'),
#                     dict(
#                         hue_shift_limit=20,
#                         p=0.3,
#                         sat_shift_limit=30,
#                         type='HueSaturationValue',
#                         val_shift_limit=20),
#                     dict(
#                         fill_value=0,
#                         max_height=60,
#                         max_holes=4,
#                         max_width=60,
#                         min_holes=1,
#                         p=0.25,
#                         type='CoarseDropout'),
#                 ],
#                 type='Albu',
#                 update_pad_shape=False),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='BaseSegDataset'),
#     num_workers=2)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             1920,
#             1080,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         640,
#         640,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         keymap=dict(gt_semantic_seg='mask', img='image'),
#         transforms=[
#             dict(blur_limit=5, p=0.3, type='MotionBlur'),
#             dict(p=0.2, type='GaussNoise', var_limit=(
#                 5,
#                 30,
#             )),
#             dict(
#                 brightness_limit=0.3,
#                 contrast_limit=0.3,
#                 p=0.4,
#                 type='RandomBrightnessContrast'),
#             dict(
#                 hue_shift_limit=20,
#                 p=0.3,
#                 sat_shift_limit=30,
#                 type='HueSaturationValue',
#                 val_shift_limit=20),
#             dict(
#                 fill_value=0,
#                 max_height=60,
#                 max_holes=4,
#                 max_width=60,
#                 min_holes=1,
#                 p=0.25,
#                 type='CoarseDropout'),
#         ],
#         type='Albu',
#         update_pad_shape=False),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(_scope_='mmseg', type='SegTTAModel')
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='val/images', seg_map_path='val/masks'),
#         data_root='/content/processed/',
#         img_suffix='.jpeg',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'board',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1920,
#                 1080,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='BaseSegDataset'),
#     num_workers=2)
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#     ], type='IoUMetric')
# val_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1920,
#         1080,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# vis_backends = [
#     dict(_scope_='mmseg', type='LocalVisBackend'),
# ]
# visualizer = dict(
#     _scope_='mmseg',
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized'
#
# /usr/local/lib/python3.12/dist-packages/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /usr/local/lib/python3.12/dist-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /usr/local/lib/python3.12/dist-packages/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 03/26 11:56:49 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/26 11:56:49 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /usr/local/lib/python3.12/dist-packages/mmseg/datasets/transforms/transforms.py:2395: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   return obj_cls(**args)
# /usr/local/lib/python3.12/dist-packages/mmseg/datasets/transforms/transforms.py:2395: UserWarning: Argument(s) 'max_holes, max_height, max_width, min_holes, fill_value' are not valid for transform CoarseDropout
#   return obj_cls(**args)
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.0.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.attn.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.0.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.attn.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.0.1.1.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.0.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.attn.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.0.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.attn.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.1.1.1.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.0.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.attn.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.0.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.attn.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.2.1.1.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.0.norm.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.0.norm.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.0.norm.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.0.norm.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.0.norm.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.0.norm.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.0.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm1.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm1.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm1.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm1.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm1.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm1.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm2.weight:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm2.weight:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm2.weight:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm2.bias:lr=3e-05
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm2.bias:weight_decay=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- backbone.layers.3.1.1.norm2.bias:decay_mult=0.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.conv_seg.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.conv_seg.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.conv_seg.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.conv_seg.bias:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.conv_seg.bias:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.conv_seg.bias:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.conv.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.conv.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.conv.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.bn.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.bn.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.bn.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.bn.bias:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.bn.bias:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.0.bn.bias:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.conv.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.conv.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.conv.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.bn.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.bn.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.bn.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.bn.bias:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.bn.bias:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.1.bn.bias:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.conv.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.conv.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.conv.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.bn.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.bn.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.bn.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.bn.bias:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.bn.bias:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.2.bn.bias:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.conv.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.conv.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.conv.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.bn.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.bn.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.bn.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.bn.bias:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.bn.bias:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.convs.3.bn.bias:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.conv.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.conv.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.conv.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.bn.weight:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.bn.weight:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.bn.weight:lr_mult=10.0
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.bn.bias:lr=0.00030000000000000003
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.bn.bias:weight_decay=0.01
# 03/26 11:56:50 - mmengine - INFO - paramwise_options -- decode_head.fusion_conv.bn.bias:lr_mult=10.0
# 03/26 11:56:51 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 03/26 11:56:52 - mmengine - INFO - load model from: /content/checkpoints/mit_b1_imagenet.pth
# 03/26 11:56:52 - mmengine - INFO - Loads checkpoint by local backend from path: /content/checkpoints/mit_b1_imagenet.pth
# /usr/local/lib/python3.12/dist-packages/mmengine/runner/checkpoint.py:347: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=map_location)
# 03/26 11:56:52 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 03/26 11:56:52 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 03/26 11:56:52 - mmengine - INFO - Checkpoints will be saved to /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized.
# 03/26 11:57:57 - mmengine - INFO - Iter(train) [   50/20000]  base_lr: 9.8068e-07 lr: 9.8068e-07  eta: 7:10:13  time: 0.8166  data_time: 0.0214  memory: 12665  loss: 0.7011  decode.loss_ce: 0.7011  decode.acc_seg: 61.5680
# 03/26 11:58:36 - mmengine - INFO - Iter(train) [  100/20000]  base_lr: 1.9813e-06 lr: 1.9813e-06  eta: 5:44:17  time: 0.7680  data_time: 0.0102  memory: 5600  loss: 0.6021  decode.loss_ce: 0.6021  decode.acc_seg: 84.1821
# 03/26 11:59:15 - mmengine - INFO - Iter(train) [  150/20000]  base_lr: 2.9820e-06 lr: 2.9820e-06  eta: 5:15:11  time: 0.7832  data_time: 0.0218  memory: 5601  loss: 0.4921  decode.loss_ce: 0.4921  decode.acc_seg: 92.7374
# 03/26 11:59:29 - mmengine - INFO - Exp name: segformer_b1_optimized_20260326_115645
# 03/26
- mmengine - INFO - Exp name: segformer_b1_optimized_20260326_115645
# 03/26 16:06:10 - mmengine - INFO - Iter(train) [18000/20000]  base_lr: 3.2434e-06 lr: 3.2434e-06  eta: 0:26:37  time: 0.7966  data_time: 0.0241  memory: 5596  loss: 0.0038  decode.loss_ce: 0.0038  decode.acc_seg: 99.8918
# 03/26 16:06:10 - mmengine - INFO - Saving checkpoint at 18000 iterations
# 03/26 16:06:35 - mmengine - INFO - Iter(val) [ 50/149]    eta: 0:00:47  time: 0.4794  data_time: 0.0092  memory: 2824
# 03/26 16:06:58 - mmengine - INFO - Iter(val) [100/149]    eta: 0:00:23  time: 0.4724  data_time: 0.0072  memory: 2824
# 03/26 16:07:21 - mmengine - INFO - per class results:
# 03/26 16:07:21 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 97.11 | 97.81 | 98.53 |
# |   board    | 75.77 | 92.61 | 86.22 |
# +------------+-------+-------+-------+
# 03/26 16:07:21 - mmengine - INFO - Iter(val) [149/149]    aAcc: 97.3500  mIoU: 86.4400  mAcc: 95.2100  mDice: 92.3700  data_time: 0.0096  time: 0.4718
# 03/26 16:08:00 - mmengine - INFO - Iter(train) [18050/20000]  base_lr: 3.1623e-06 lr: 3.1623e-06  eta: 0:25:57  time: 0.7999  data_time: 0.0234  memory: 5594  loss: 0.0037  decode.loss_ce: 0.0037  decode.acc_seg: 99.9745
# 03/26 16:08:39 - mmengine - INFO - Iter(train) [18100/20000]  base_lr: 3.0812e-06 lr: 3.0812e-06  eta: 0:25:17  time: 0.7537  data_time: 0.0111  memory: 5596  loss: 0.0056  decode.loss_ce: 0.0056  decode.acc_seg: 99.8957
# 03/26 16:09:21 - mmengine - INFO - Iter(train) [18150/20000]  base_lr: 3.0002e-06 lr: 3.0002e-06  eta: 0:24:37  time: 1.0590  data_time: 0.3153  memory: 5596  loss: 0.0047  decode.loss_ce: 0.0047  decode.acc_seg: 99.9196
# 03/26 16:10:00 - mmengine - INFO - Iter(train) [18200/20000]  base_lr: 2.9191e-06 lr: 2.9191e-06  eta: 0:23:57  time: 0.7999  data_time: 0.0228  memory: 5596  loss: 0.0052  decode.loss_ce: 0.0052  decode.acc_seg: 99.6229
# 03/26 16:10:39 - mmengine - INFO - Iter(train) [18250/20000]  base_lr: 2.8380e-06 lr: 2.8380e-06  eta: 0:23:17  time: 0.7690  data_time: 0.0104  memory: 5594  loss: 0.0080  decode.loss_ce: 0.0080  decode.acc_seg: 99.7365
# 03/26 16:11:18 - mmengine - INFO - Iter(train) [18300/20000]  base_lr: 2.7569e-06 lr: 2.7569e-06  eta: 0:22:37  time: 0.7882  data_time: 0.0263  memory: 5596  loss: 0.0038  decode.loss_ce: 0.0038  decode.acc_seg: 99.8201
# 03/26 16:12:00 - mmengine - INFO - Iter(train) [18350/20000]  base_lr: 2.6758e-06 lr: 2.6758e-06  eta: 0:21:57  time: 0.7834  data_time: 0.0285  memory: 5596  loss: 0.0021  decode.loss_ce: 0.0021  decode.acc_seg: 99.9144
loss: 0.0033  decode.loss_ce: 0.0033  decode.acc_seg: 99.9222
# 03/26 16:27:56 - mmengine - INFO - Iter(train) [19550/20000]  base_lr: 7.2977e-07 lr: 7.2977e-07  eta: 0:05:59  time: 0.7563  data_time: 0.0113  memory: 5594  loss: 0.0058  decode.loss_ce: 0.0058  decode.acc_seg: 100.0000
# 03/26 16:28:35 - mmengine - INFO - Iter(train) [19600/20000]  base_lr: 6.4868e-07 lr: 6.4868e-07  eta: 0:05:19  time: 0.7917  data_time: 0.0178  memory: 5596  loss: 0.0075  decode.loss_ce: 0.0075  decode.acc_seg: 99.7578
# 03/26 16:29:13 - mmengine - INFO - Iter(train) [19650/20000]  base_lr: 5.6760e-07 lr: 5.6760e-07  eta: 0:04:39  time: 0.7882  data_time: 0.0213  memory: 5596  loss: 0.0033  decode.loss_ce: 0.0033  decode.acc_seg: 99.9132
# 03/26 16:29:55 - mmengine - INFO - Iter(train) [19700/20000]  base_lr: 4.8651e-07 lr: 4.8651e-07  eta: 0:03:59  time: 0.7614  data_time: 0.0115  memory: 5596  loss: 0.0023  decode.loss_ce: 0.0023  decode.acc_seg: 99.7894
# 03/26 16:30:34 - mmengine - INFO - Iter(train) [19750/20000]  base_lr: 4.0543e-07 lr: 4.0543e-07  eta: 0:03:19  time: 0.7794  data_time: 0.0237  memory: 5594  loss: 0.0033  decode.loss_ce: 0.0033  decode.acc_seg: 99.7985
# 03/26 16:31:13 - mmengine - INFO - Iter(train) [19800/20000]  base_lr: 3.2434e-07 lr: 3.2434e-07  eta: 0:02:39  time: 0.7748  data_time: 0.0187  memory: 5596  loss: 0.0050  decode.loss_ce: 0.0050  decode.acc_seg: 99.6923
# 03/26 16:31:55 - mmengine - INFO - Iter(train) [19850/20000]  base_lr: 2.4326e-07 lr: 2.4326e-07  eta: 0:01:59  time: 0.7738  data_time: 0.0105  memory: 5596  loss: 0.0038  decode.loss_ce: 0.0038  decode.acc_seg: 99.8780
# 03/26 16:32:34 - mmengine - INFO - Iter(train) [19900/20000]  base_lr: 1.6217e-07 lr: 1.6217e-07  eta: 0:01:19  time: 0.7989  data_time: 0.0230  memory: 5594  loss: 0.0035  decode.loss_ce: 0.0035  decode.acc_seg: 99.9133
# 03/26 16:33:12 - mmengine - INFO - Iter(train) [19950/20000]  base_lr: 8.1085e-08 lr: 8.1085e-08  eta: 0:00:39  time: 0.7614  data_time: 0.0149  memory: 5596  loss: 0.0052  decode.loss_ce: 0.0052  decode.acc_seg: 99.8120
# 03/26 16:33:54 - mmengine - INFO - Exp name: segformer_b1_optimized_20260326_115645
# 03/26 16:33:54 - mmengine - INFO - Iter(train) [20000/20000]  base_lr: 0.0000e+00 lr: 0.0000e+00  eta: 0:00:00  time: 1.0422  data_time: 0.2999  memory: 5596  loss: 0.0036  decode.loss_ce: 0.0036  decode.acc_seg: 99.8552
# 03/26 16:33:54 - mmengine - INFO - Saving checkpoint at 20000 iterations
# 03/26 16:34:19 - mmengine - INFO - Iter(val) [ 50/149]    eta: 0:00:47  time: 0.4653  data_time: 0.0070  memory: 2824
# 03/26 16:34:43 - mmengine - INFO - Iter(val) [100/149]    eta: 0:00:23  time: 0.4683  data_time: 0.0097  memory: 2824
# 03/26 16:35:06 - mmengine - INFO - per class results:
# 03/26 16:35:06 - mmengine - INFO -
# +------------+-------+-------+-------+
# |   Class    |  IoU  |  Acc  |  Dice |
# +------------+-------+-------+-------+
# | background | 97.14 | 97.92 | 98.55 |
# |   board    | 75.85 | 91.85 | 86.27 |
# +------------+-------+-------+-------+
# 03/26 16:35:06 - mmengine - INFO - Iter(val) [149/149]    aAcc: 97.3800  mIoU: 86.5000  mAcc: 94.8800  mDice: 92.4100  data_time: 0.0102  time: 0.4718

# %%
# ============================================================
# CELL 9 - Verify Optimized Results on Google Drive
# ============================================================

drive_results = "/content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized"

print("Checkpoints saved on Drive:")
# !ls -lh {drive_results}/*.pth 2>/dev/null || echo "  No checkpoints yet"

print("\nLast checkpoint:")
# !cat {drive_results}/last_checkpoint 2>/dev/null || echo "  Not found"
# Out:
# Checkpoints saved on Drive:
# -rw------- 1 root root  59M Mar 26 15:11 /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/best_mIoU_iter_14000.pth
# -rw------- 1 root root 171M Mar 26 15:38 /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/iter_16000.pth
# -rw------- 1 root root 172M Mar 26 16:06 /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/iter_18000.pth
# -rw------- 1 root root 172M Mar 26 16:33 /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/iter_20000.pth
#
# Last checkpoint:
# /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/iter_20000.pth

# %%
# ============================================================
# CELL 10 - Evaluate B1 Optimized with Full Metrics
# mIoU, mDice, Precision, Recall on TEST SET
# Uses best checkpoint saved on Google Drive
# ============================================================

import mmseg, os, glob

mmseg_test = os.path.join(
    os.path.dirname(mmseg.__file__),
    '.mim', 'tools', 'test.py'
)

# Automatically find best checkpoint on Drive
checkpoints = glob.glob(
    '/content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/best_mIoU_iter_*.pth'
)

if not checkpoints:
    print("No checkpoint found! Check Drive path.")
else:
    best_checkpoint = max(
        checkpoints,
        key=lambda x: int(x.split('iter_')[1].split('.')[0])
    )
    print(f"Using checkpoint: {best_checkpoint}")

    # test_dataloader  → test/images + test/masks (146 immagini)
    # test_evaluator   → mIoU, mDice, mFscore (Precision + Recall)
    # !python {mmseg_test} \
        /content/repo/configs/segformer_b1_optimized.py \
        {best_checkpoint}
# Out:
# Using checkpoint: /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/best_mIoU_iter_14000.pth
# /usr/local/lib/python3.12/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 03/27 02:45:58 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1677502742
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.8, V12.8.93
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04.3) 11.4.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.4.2 (Git Hash 1137e04ec0b5251ca2b4400a4fd3c667ce843d67)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.1  (built against CUDA 12.4)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.4.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.19.1+cu121
#     OpenCV: 4.13.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1677502742
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 03/27 02:45:58 - mmengine - INFO - Config:
# crop_size = (
#     640,
#     640,
# )
# custom_hooks = [
#     dict(
#         min_delta=0.001,
#         monitor='mIoU',
#         patience=5,
#         rule='greater',
#         type='EarlyStoppingHook'),
# ]
# data_preprocessor = dict(
#     _scope_='mmseg',
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = '/content/processed/'
# dataset_type = 'BaseSegDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=2000,
#         max_keep_ckpts=3,
#         rule='greater',
#         save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = '/content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/best_mIoU_iter_14000.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# meta = dict(
#     classes=(
#         'background',
#         'board',
#     ), palette=[
#         [
#             0,
#             0,
#             0,
#         ],
#         [
#             255,
#             0,
#             0,
#         ],
#     ])
# model = dict(
#     _scope_='mmseg',
#     backbone=dict(
#         attn_drop_rate=0.0,
#         drop_path_rate=0.1,
#         drop_rate=0.0,
#         embed_dims=64,
#         in_channels=3,
#         init_cfg=dict(
#             checkpoint='/content/checkpoints/mit_b1_imagenet.pth',
#             type='Pretrained'),
#         mlp_ratio=4,
#         num_heads=[
#             1,
#             2,
#             5,
#             8,
#         ],
#         num_layers=[
#             2,
#             2,
#             2,
#             2,
#         ],
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_sizes=[
#             7,
#             3,
#             3,
#             3,
#         ],
#         qkv_bias=True,
#         sr_ratios=[
#             8,
#             4,
#             2,
#             1,
#         ],
#         type='MixVisionTransformer'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             640,
#             640,
#         ),
#         size_divisor=None,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         align_corners=False,
#         channels=512,
#         dropout_ratio=0.1,
#         in_channels=[
#             64,
#             128,
#             320,
#             512,
#         ],
#         in_index=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         loss_decode=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=2,
#         type='SegformerHead'),
#     pretrained=None,
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(_scope_='mmseg', requires_grad=True, type='SyncBN')
# optim_wrapper = dict(
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=3e-05, type='AdamW', weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             head=dict(lr_mult=10.0),
#             norm=dict(decay_mult=0.0),
#             pos_block=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# optimizer = dict(
#     betas=(
#         0.9,
#         0.999,
#     ), lr=3e-05, type='AdamW', weight_decay=0.01)
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1500, start_factor=1e-06,
#         type='LinearLR'),
#     dict(
#         begin=1500,
#         by_epoch=False,
#         end=20000,
#         eta_min=0.0,
#         power=1.0,
#         type='PolyLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='test/images', seg_map_path='test/masks'),
#         data_root='/content/processed/',
#         img_suffix='.jpeg',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'board',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1920,
#                 1080,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='BaseSegDataset'),
#     num_workers=2)
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ], type='IoUMetric')
# train_cfg = dict(max_iters=20000, type='IterBasedTrainLoop', val_interval=2000)
# train_dataloader = dict(
#     batch_size=4,
#     dataset=dict(
#         data_prefix=dict(img_path='train/images', seg_map_path='train/masks'),
#         data_root='/content/processed/',
#         img_suffix='.jpeg',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'board',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     1920,
#                     1080,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     640,
#                     640,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(
#                 keymap=dict(gt_semantic_seg='mask', img='image'),
#                 transforms=[
#                     dict(blur_limit=5, p=0.3, type='MotionBlur'),
#                     dict(p=0.2, type='GaussNoise', var_limit=(
#                         5,
#                         30,
#                     )),
#                     dict(
#                         brightness_limit=0.3,
#                         contrast_limit=0.3,
#                         p=0.4,
#                         type='RandomBrightnessContrast'),
#                     dict(
#                         hue_shift_limit=20,
#                         p=0.3,
#                         sat_shift_limit=30,
#                         type='HueSaturationValue',
#                         val_shift_limit=20),
#                     dict(
#                         fill_value=0,
#                         max_height=60,
#                         max_holes=4,
#                         max_width=60,
#                         min_holes=1,
#                         p=0.25,
#                         type='CoarseDropout'),
#                 ],
#                 type='Albu',
#                 update_pad_shape=False),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='BaseSegDataset'),
#     num_workers=2)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             1920,
#             1080,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         640,
#         640,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(
#         keymap=dict(gt_semantic_seg='mask', img='image'),
#         transforms=[
#             dict(blur_limit=5, p=0.3, type='MotionBlur'),
#             dict(p=0.2, type='GaussNoise', var_limit=(
#                 5,
#                 30,
#             )),
#             dict(
#                 brightness_limit=0.3,
#                 contrast_limit=0.3,
#                 p=0.4,
#                 type='RandomBrightnessContrast'),
#             dict(
#                 hue_shift_limit=20,
#                 p=0.3,
#                 sat_shift_limit=30,
#                 type='HueSaturationValue',
#                 val_shift_limit=20),
#             dict(
#                 fill_value=0,
#                 max_height=60,
#                 max_holes=4,
#                 max_width=60,
#                 min_holes=1,
#                 p=0.25,
#                 type='CoarseDropout'),
#         ],
#         type='Albu',
#         update_pad_shape=False),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(_scope_='mmseg', type='SegTTAModel')
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='val/images', seg_map_path='val/masks'),
#         data_root='/content/processed/',
#         img_suffix='.jpeg',
#         metainfo=dict(
#             classes=(
#                 'background',
#                 'board',
#             ),
#             palette=[
#                 [
#                     0,
#                     0,
#                     0,
#                 ],
#                 [
#                     255,
#                     0,
#                     0,
#                 ],
#             ]),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1920,
#                 1080,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         seg_map_suffix='.png',
#         type='BaseSegDataset'),
#     num_workers=2)
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#     ], type='IoUMetric')
# val_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1920,
#         1080,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# vis_backends = [
#     dict(_scope_='mmseg', type='LocalVisBackend'),
# ]
# visualizer = dict(
#     _scope_='mmseg',
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/segformer_b1_optimized'
#
# /usr/local/lib/python3.12/dist-packages/mmseg/models/decode_heads/decode_head.py:120: UserWarning: For binary segmentation, we suggest using`out_channels = 1` to define the outputchannels of segmentor, and use `threshold`to convert `seg_logits` into a predictionapplying a threshold
#   warnings.warn('For binary segmentation, we suggest using'
# /usr/local/lib/python3.12/dist-packages/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /usr/local/lib/python3.12/dist-packages/mmseg/models/losses/cross_entropy_loss.py:250: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 03/27 02:46:01 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 03/27 02:46:01 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 03/27 02:46:02 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# /usr/local/lib/python3.12/dist-packages/mmseg/datasets/transforms/transforms.py:2395: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   return obj_cls(**args)
# /usr/local/lib/python3.12/dist-packages/mmseg/datasets/transforms/transforms.py:2395: UserWarning: Argument(s) 'max_holes, max_height, max_width, min_holes, fill_value' are not valid for transform CoarseDropout
#   return obj_cls(**args)
# Loads checkpoint by local backend from path: /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/best_mIoU_iter_14000.pth
# /usr/local/lib/python3.12/dist-packages/mmengine/runner/checkpoint.py:347: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, map_location=map_location)
# 03/27 02:46:03 - mmengine - INFO - Load checkpoint from /content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized/best_mIoU_iter_14000.pth
# 03/27 02:46:28 - mmengine - INFO - Iter(test) [ 50/146]    eta: 0:00:47  time: 0.4026  data_time: 0.0079  memory: 9399
# 03/27 02:46:49 - mmengine - INFO - Iter(test) [100/146]    eta: 0:00:21  time: 0.4305  data_time: 0.0105  memory: 2697
# 03/27 02:47:09 - mmengine - INFO - per class results:
# 03/27 02:47:09 - mmengine - INFO -
# +------------+-------+-------+-------+--------+-----------+--------+
# |   Class    |  IoU  |  Acc  |  Dice | Fscore | Precision | Recall |
# +------------+-------+-------+-------+--------+-----------+--------+
# | background | 97.48 | 98.25 | 98.72 | 98.72  |    99.2   | 98.25  |
# |   board    | 71.68 | 88.99 | 83.51 | 83.51  |   78.66   | 88.99  |
# +------------+-------+-------+-------+--------+-----------+--------+
# 03/27 02:47:09 - mmengine - INFO - Iter(test) [146/146]    aAcc: 97.6300  mIoU: 84.5800  mAcc: 93.6200  mDice: 91.1100  mFscore: 91.1100  mPrecision: 88.9300  mRecall: 93.6200  data_time: 0.0129  time: 0.4502

# %%
# ============================================================
# CELL 11 - Save Logs and Push to GitHub
# Copies B1 optimized training logs from Drive to GitHub repo
# ============================================================

import os, glob, shutil

# ── Create directories ────────────────────────────────────────────────────────
os.makedirs('/content/repo/results/exp3_segformer_b1_optimized', exist_ok=True)
os.makedirs('/content/repo/models', exist_ok=True)

# ── Copy training logs from Drive to results/ ─────────────────────────────────
src = '/content/drive/MyDrive/advertising_panel_segmentation/results/exp3_segformer_b1_optimized'
dst = '/content/repo/results/exp3_segformer_b1_optimized'

log_files = glob.glob(f'{src}/**/*.log', recursive=True)
if log_files:
    for log_file in log_files:
        shutil.copy(log_file, dst)
        print(f"Copied: {os.path.basename(log_file)} → results/exp3_segformer_b1_optimized/")
else:
    print(f"No log files found in {src}")

# ── Update models/README.md ───────────────────────────────────────────────────
readme_path = '/content/repo/models/README.md'
existing = ""
if os.path.exists(readme_path):
    with open(readme_path, 'r') as f:
        existing = f.read()

b1_opt_entry = """
## Exp3 - SegFormer-B1 Optimized
- Best checkpoint: best_mIoU_iter_14000.pth
- mIoU: 84.58%
- board IoU: 71.68%
- Dice: 83.51%
- Precision: 78.66%
- Recall: 88.99%
- Stored on: Google Drive
"""

if 'Exp3' not in existing:
    with open(readme_path, 'a') as f:
        f.write(b1_opt_entry)
    print("Updated models/README.md with Exp3 entry")
else:
    print("Exp3 entry already present in models/README.md")

# ── Verify no .pth files exist ───────────────────────────────────────────────
pth_files = glob.glob('/content/repo/results/**/*.pth', recursive=True)
if pth_files:
    print("WARNING: .pth files found! Removing...")
    for f in pth_files:
        os.remove(f)
        print(f"Removed: {f}")
else:
    print("No .pth files found - safe to push!")

# ── Push to GitHub ────────────────────────────────────────────────────────────
from getpass import getpass
GITHUB_TOKEN = getpass("Enter GitHub token: ")

# !cd /content/repo && git config user.email "massimilianogiangreco7@gmail.com"
# !cd /content/repo && git config user.name "ilMassy"
# !cd /content/repo && git remote set-url origin \
    https://{GITHUB_TOKEN}@github.com/ilMassy/advertising-panel-segmentation.git
# !cd /content/repo && git pull origin main --rebase

# !cd /content/repo && git add results/exp3_segformer_b1_optimized/*.log
# !cd /content/repo && git add models/README.md

print("\n=== Files to be committed ===")
# !cd /content/repo && git diff --cached --name-only

# !cd /content/repo && git commit -m "Add B1 optimized training logs and model summary (Phase 5)" \
    || echo "Nothing to commit"
# !cd /content/repo && git push origin main
print("Pushed to GitHub!")
# Out:
# Copied: 20260326_115645.log → results/exp3_segformer_b1_optimized/
# Updated models/README.md with Exp3 entry
# No .pth files found - safe to push!
# Enter GitHub token: ··········
# error: cannot pull with rebase: You have unstaged changes.
# error: please commit or stash them.
#
# === Files to be committed ===
# models/README.md
# results/exp3_segformer_b1_optimized/20260326_115645.log
# [main 7850101] Add B1 optimized training logs and model summary (Phase 5)
#  2 files changed, 1851 insertions(+)
#  create mode 100644 results/exp3_segformer_b1_optimized/20260326_115645.log
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (7/7), 22.67 KiB | 4.53 MiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/ilMassy/advertising-panel-segmentation.git
#    80b137c..7850101  main -> main
# Pushed to GitHub!
